# %%
import pandas as pd, plotly.express as px, seaborn as sns, matplotlib.pyplot as plt

# %%
df = pd.read_csv("./clean_data_1.csv")

# %%
df.head(3)
# Out:
#   NMS Service Plan Id       Phone          Parent Account: Account Name  \
# 0             NC010G1  8030428639                Kat Consulting Hyperia
# 1             NC005G1  8037848784  Marvit High Quality Services Hyperia
# 2                 NaN           0       Marcorex Telco Services Hyperia
#
#   Latest Decommission Date  DSS Order ID   FSO ID Enterprise ID  \
# 0                5/18/2020           NaN  3526981           NaN
# 1                 1/4/2023           NaN  3524211           NaN
# 2                 1/4/2023           NaN  3529091           NaN
#
#    Distributor Partner Id Satellite Gateway Name  ... Last Modified Date  \
# 0                     NaN       Y1B       Y1BLXB  ...          5/19/2020
# 1                     NaN       Y1B       Y1BLXB  ...           1/4/2023
# 2                     NaN       Y1B       Y1BLXB  ...           1/4/2023
#
#     Modem Beam Id    Offer/Plan Name  Offer Description Serial Number  \
# 0  HN9600  Y1B051                NaN                NaN       2628178
# 1  HN9600  Y1B051                NaN                NaN       2542110
# 2  HN9600  Y1B051  YahClick Pro 20GB  YahClick Pro 20GB       2628267
#
#   Location Status       Lat      Long  \
# 0        Inactive  4.916667  6.316667
# 1        Inactive  4.916667  6.316667
# 2        Inactive  4.916667  6.316667
#
#                                             Location
# 0  #52 Mike Okporkpor  Kpansia   Yenagoa  Bayelsa...
# 1  #52 Mike Okporkpor  Kpansia   Yenagoa  Bayelsa...
# 2  #52 Mike Okporkpor  Kpansia   Yenagoa  Bayelsa...
#
# [3 rows x 23 columns]

# %%
states_in_nigeria = [
    "Abia", "Adamawa","Akwa Ibom","Anambra",
    "Bauchi","Bayelsa","Benue","Borno",
    "Cross River","Delta",
    "Ebonyi","Edo","Ekiti","Enugu",
    "Gombe","Imo","Jigawa","Kaduna",
    "Kano","Katsina","Kebbi","Kogi","Kwara","Lagos", 
    "Nasarawa","Niger", "Ogun","Ondo", "Osun","Oyo",
    "Plateau","Rivers", "Sokoto","Taraba","Yobe",
    "Zamfara","Federal Capital Territory"
]
def is_state_in_nigeria(location):
    for state in states_in_nigeria:
        if state in location:
            return state
    return False

# %%
df['state'] = df['Location'].apply(is_state_in_nigeria)
df['state']
# Out:
# 0         Bayelsa
# 1         Bayelsa
# 2         Bayelsa
# 3       Akwa Ibom
# 4       Akwa Ibom
#           ...
# 4431      Katsina
# 4432      Katsina
# 4433      Katsina
# 4434      Katsina
# 4435      Katsina
# Name: state, Length: 4436, dtype: object

# %%
df.head(3)
# Out:
#   NMS Service Plan Id       Phone          Parent Account: Account Name  \
# 0             NC010G1  8030428639                Kat Consulting Hyperia
# 1             NC005G1  8037848784  Marvit High Quality Services Hyperia
# 2                 NaN           0       Marcorex Telco Services Hyperia
#
#   Latest Decommission Date  DSS Order ID   FSO ID Enterprise ID  \
# 0                5/18/2020           NaN  3526981           NaN
# 1                 1/4/2023           NaN  3524211           NaN
# 2                 1/4/2023           NaN  3529091           NaN
#
#    Distributor Partner Id Satellite Gateway Name  ...   Modem Beam Id  \
# 0                     NaN       Y1B       Y1BLXB  ...  HN9600  Y1B051
# 1                     NaN       Y1B       Y1BLXB  ...  HN9600  Y1B051
# 2                     NaN       Y1B       Y1BLXB  ...  HN9600  Y1B051
#
#      Offer/Plan Name  Offer Description Serial Number Location Status  \
# 0                NaN                NaN       2628178        Inactive
# 1                NaN                NaN       2542110        Inactive
# 2  YahClick Pro 20GB  YahClick Pro 20GB       2628267        Inactive
#
#         Lat      Long                                           Location  \
# 0  4.916667  6.316667  #52 Mike Okporkpor  Kpansia   Yenagoa  Bayelsa...
# 1  4.916667  6.316667  #52 Mike Okporkpor  Kpansia   Yenagoa  Bayelsa...
# 2  4.916667  6.316667  #52 Mike Okporkpor  Kpansia   Yenagoa  Bayelsa...
#
#      state
# 0  Bayelsa
# 1  Bayelsa
# 2  Bayelsa
#
# [3 rows x 24 columns]

# %%
df.to_csv("./clean_data_2.csv", index=False)
