# %%
pip install googlemaps
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40750 sha256=42438b40f6a3adbef58401e89b0c73e17783eec7816f02320702002998b88875
#   Stored in directory: c:\users\liudo\appdata\local\pip\cache\wheels\f1\09\77\3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# ...

# %%
import pandas as pd, numpy as np, seaborn as sns,matplotlib.pyplot as plt, plotly.express as px, requests as rqs, json, googlemaps

# %%
df = pd.read_excel("./Termination_Dump_31072023 with coordinates.xlsx")
df.head()
# Out:
#   NMS Service Plan Id           Lat, Long           Phone  \
# 0             NC020G1  4.956944, 6.361944     08032582277
# 1             NC010G1          6.47, 6.09     08020575565
# 2             NC010G1     9.24, 12.439722  (234) 146-1991
# 3             NC010G1    5.483333, 5.1975     08032345321
# 4             NC010G1  5.350556, 5.351667     08032345321
#
#       Parent Account: Account Name Latest Decommission Date  DSS Order ID  \
# 0  Marcorex Telco Services Hyperia               2018-04-13           NaN
# 1         GETACHUS NIG LTD Hyperia               2018-04-16           NaN
# 2         Etchgold Nigeria Limited               2018-04-10           NaN
# 3              SDC Limited Hyperia               2018-04-26           NaN
# 4              SDC Limited Hyperia               2018-04-27           NaN
#
#     FSO ID Enterprise ID  Distributor Partner Id Satellite  ...  Transponder  \
# 0  3521532           NaN                     NaN       Y1B  ...  Y1B-B51-OR1
# ...

# %%
df[["Lat", "Long"]] = df['Lat, Long'].str.split(",", expand=True).astype(float)
df.drop(columns="Lat, Long", inplace=True)

# %%
df.head()
# Out:
#   NMS Service Plan Id           Phone     Parent Account: Account Name  \
# 0             NC020G1     08032582277  Marcorex Telco Services Hyperia
# 1             NC010G1     08020575565         GETACHUS NIG LTD Hyperia
# 2             NC010G1  (234) 146-1991         Etchgold Nigeria Limited
# 3             NC010G1     08032345321              SDC Limited Hyperia
# 4             NC010G1     08032345321              SDC Limited Hyperia
#
#   Latest Decommission Date  DSS Order ID   FSO ID Enterprise ID  \
# 0               2018-04-13           NaN  3521532           NaN
# 1               2018-04-16           NaN  3619771           NaN
# 2               2018-04-10           NaN  3373588      SKY01326
# 3               2018-04-26           NaN  3587734           NaN
# 4               2018-04-27           NaN  3587813           NaN
#
#    Distributor Partner Id Satellite Gateway Name  ... Latest Commission Date  \
# ...

# %%
fig = px.scatter_mapbox(
    df,
    lat = "Lat",
    lon = "Long",
    width = 900,
    height = 600,
    color = "Modem",
    hover_data = ["Modem"],
    
)
fig.update_layout(mapbox_style="open-street-map")
fig.show()

# %%
latitude = df["Lat"]
longitude = df["Long"]

# %%
api_keys = "AIzaSyDduak3nwu3pZQ-Z_1yGyZTT8yRLkykg5U"

# %%
def reverse_geocode(lat, long, api_keys):
    gmaps = googlemaps.Client(key=api_keys)
    result = gmaps.reverse_geocode((lat, long))
    if result:
        return result[0]["formatted_address"]
    else:
        return "Nof location data available"

# %%
df["location"] = df.apply(lambda row: reverse_geocode(row["Lat"], row["Long"],api_keys), axis=1)

# %%
df.head()
