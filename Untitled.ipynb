# %%
import pandas as pd, plotly.express as px

# %%
df = pd.read_csv("./clean_data_4.csv")
df.head(3)
# Out:
#   NMS Service Plan Id       Lat       Long           Phone  \
# 0             NC020G1  4.956944   6.361944      8032582277
# 1             NC010G1  6.470000   6.090000      8020575565
# 2             NC010G1  9.240000  12.439722  (234) 146-1991
#
#       Parent Account: Account Name Latest Decommission Date  DSS Order ID  \
# 0  Marcorex Telco Services Hyperia                4/13/2018           NaN
# 1         GETACHUS NIG LTD Hyperia                4/16/2018           NaN
# 2         Etchgold Nigeria Limited                4/10/2018           NaN
#
#     FSO ID Enterprise ID  Distributor Partner Id  ... Latest Commission Date  \
# 0  3521532           NaN                     NaN  ...              3/15/2016
# 1  3619771           NaN                     NaN  ...              3/19/2018
# 2  3373588      SKY01326                     NaN  ...              4/16/2014
#
#   Last Modified Date   Modem Beam Id        Offer/Plan Name Offer Description  \
# 0          4/17/2018  HN9600  Y1B051  YahClick Empower 20GB               NaN
# 1          4/17/2018  HN9260  Y1B051     YahClick Lite 10GB               NaN
# 2          4/17/2018  HN9800  Y1B061     YahClick Lite 10GB               NaN
#
#   Serial Number Location Status  \
# 0       2628267        Inactive
# 1       2332146        Inactive
# 2       2482968        Inactive
#
#                                             location    state
# 0  X947+V47, Mbiama-Yenagoa Road, 569101, Yenagoa...  Bayelsa
# 1  F39R+X2 Ebute-Ujogba,  _Uhi, Edo,  _301113, Ed...      Edo
# 2  6CQQ+XV Jimeta,  _6CRQ+27Q, Barracks Road, Kar...  Adamawa
#
# [3 rows x 24 columns]

# %%
df.drop(columns="location", axis=1, inplace=True)

# %%
df.head(3)
# Out:
#   NMS Service Plan Id       Lat       Long           Phone  \
# 0             NC020G1  4.956944   6.361944      8032582277
# 1             NC010G1  6.470000   6.090000      8020575565
# 2             NC010G1  9.240000  12.439722  (234) 146-1991
#
#       Parent Account: Account Name Latest Decommission Date  DSS Order ID  \
# 0  Marcorex Telco Services Hyperia                4/13/2018           NaN
# 1         GETACHUS NIG LTD Hyperia                4/16/2018           NaN
# 2         Etchgold Nigeria Limited                4/10/2018           NaN
#
#     FSO ID Enterprise ID  Distributor Partner Id  ... Created Date  \
# 0  3521532           NaN                     NaN  ...    4/10/2018
# 1  3619771           NaN                     NaN  ...    4/10/2018
# 2  3373588      SKY01326                     NaN  ...    4/10/2018
#
#   Latest Commission Date Last Modified Date   Modem Beam Id  \
# 0              3/15/2016          4/17/2018  HN9600  Y1B051
# 1              3/19/2018          4/17/2018  HN9260  Y1B051
# 2              4/16/2014          4/17/2018  HN9800  Y1B061
#
#          Offer/Plan Name Offer Description Serial Number Location Status  \
# 0  YahClick Empower 20GB               NaN       2628267        Inactive
# 1     YahClick Lite 10GB               NaN       2332146        Inactive
# 2     YahClick Lite 10GB               NaN       2482968        Inactive
#
#      state
# 0  Bayelsa
# 1      Edo
# 2  Adamawa
#
# [3 rows x 23 columns]

# %%
df.select_dtypes("object").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4436 entries, 0 to 4435
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   NMS Service Plan Id           2833 non-null   object
#  1   Phone                         4435 non-null   object
#  2   Parent Account: Account Name  4436 non-null   object
#  3   Latest Decommission Date      4436 non-null   object
#  4   Enterprise ID                 1303 non-null   object
#  5   Satellite                     4436 non-null   object
#  6   Gateway Name                  4323 non-null   object
#  7   Transponder                   4042 non-null   object
#  8   Created Date                  4436 non-null   object
#  9   Latest Commission Date        4436 non-null   object
#  10  Last Modified Date            4436 non-null   object
#  11  Modem                         4436 non-null   object
#  12  Beam Id                       4435 non-null   object
#  13  Offer/Plan Name               2678 non-null   object
#  14  Offer Description             2561 non-null   object
#  15  Location Status               4436 non-null   object
#  16  state                         4272 non-null   object
# dtypes: object(17)
# memory usage: 589.3+ KB

# %%
fig = px.scatter_mapbox(
df,
lat = "Lat",
lon = " Long",
width = 900,
height=700,
  color = "state",
    hover_data = ["Modem"],
    
)
fig.update_layout(mapbox_style="open-street-map")
fig.show()

# %%
df.groupby('state')["Modem"].count().head(5).sort_values(ascending=False)
# Out:
# state
# Adamawa      157
# Akwa Ibom    136
# Abia         128
# Anambra      127
# Bauchi        98
# Name: Modem, dtype: int64

# %%
df.state.isna().sum()
# Out:
# 164
